# %% [markdown]
# AARON MORGAN

# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
# Get a list of column names and types
columns = inspector.get_columns('measurement')
for c in columns:
    print(c['name'], c["type"])
# columns
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# Get a list of column names and types
columns = inspector.get_columns('station')
for c in columns:
    print(c['name'], c["type"])
# columns
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
measurementAll = """
                    SELECT
                        *
                    FROM
                        measurement
                    LIMIT 10
                """
engine.execute(measurementAll).fetchall()
# Out:
# [(1, 'USC00519397', '2010-01-01', 0.08, 65.0),
#  (2, 'USC00519397', '2010-01-02', 0.0, 63.0),
#  (3, 'USC00519397', '2010-01-03', 0.0, 74.0),
#  (4, 'USC00519397', '2010-01-04', 0.0, 76.0),
#  (5, 'USC00519397', '2010-01-06', None, 73.0),
#  (6, 'USC00519397', '2010-01-07', 0.06, 70.0),
#  (7, 'USC00519397', '2010-01-08', 0.0, 64.0),
#  (8, 'USC00519397', '2010-01-09', 0.0, 68.0),
#  (9, 'USC00519397', '2010-01-10', 0.0, 73.0),
#  (10, 'USC00519397', '2010-01-11', 0.01, 64.0)]

# %%
stationAll = """
                    SELECT
                        *
                    FROM
                        station
                    LIMIT 10
                """
engine.execute(stationAll).fetchall()
# Out:
# [(1, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (2, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (3, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (4, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (5, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (6, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (7, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (8, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (9, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4)]

# %%
dateQuery = """
            SELECT
                MAX(date)
            FROM
                measurement
            """
endDate = engine.execute(dateQuery).fetchall()[0][0]
endDate
# Out:
# '2017-08-23'

# %%
endDate = dt.datetime.fromisoformat(endDate).date()
startDate = endDate  - dt.timedelta(days=365)

print(endDate)
print(startDate)
# Out:
# 2017-08-23
# 2016-08-23

# %%
precipQuery = f"""
                SELECT
                    date,
                    prcp
                FROM
                    measurement
                WHERE
                    date > '{startDate}'
                    AND date <= '{endDate}'
                """
engine.execute(precipQuery).fetchall()
# Out:
# [('2016-08-24', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-26', 0.0),
#  ('2016-08-27', 0.0),
#  ('2016-08-28', 0.01),
#  ('2016-08-29', 0.0),
#  ('2016-08-30', 0.0),
#  ('2016-08-31', 0.13),
#  ('2016-09-01', 0.0),
#  ('2016-09-02', 0.0),
#  ('2016-09-03', 0.0),
#  ('2016-09-04', 0.03),
#  ('2016-09-05', None),
#  ('2016-09-06', None),
#  ('2016-09-07', 0.05),
#  ('2016-09-08', 0.0),
#  ('2016-09-09', 0.03),
#  ('2016-09-10', 0.0),
#  ('2016-09-11', 0.05),
#  ('2016-09-12', 0.0),
#  ('2016-09-13', 0.02),
#  ('2016-09-14', 1.32),
#  ('2016-09-15', 0.42),
#  ('2016-09-16', 0.06),
#  ('2016-09-17', 0.05),
#  ('2016-09-18', 0.0),
#  ('2016-09-19', 0.0),
#  ('2016-09-20', 0.0),
#  ('2016-09-21', 0.0),
#  ('2016-09-22', 0.02),
#  ('2016-09-23', 0.0),
#  ('2016-09-24', 0.0),
#  ('2016-09-25', 0.0),
#  ('2016-09-26', 0.06),
#  ('2016-09-27', 0.02),
#  ('2016-09-28', 0.0),
#  ('2016-09-29', 0.0),
#  ('2016-09-30', 0.0),
#  ('2016-10-01', 0.0),
#  ('2016-10-02', 0.0),
# ...

# %%
conn = engine.connect()

# %%
df = pd.read_sql(precipQuery, conn)
df.head()
# Out:
#          date  prcp
# 0  2016-08-24  0.08
# 1  2016-08-25  0.08
# 2  2016-08-26  0.00
# 3  2016-08-27  0.00
# 4  2016-08-28  0.01

# %%
precipResults = engine.execute(precipQuery).fetchall()
df2 = pd.DataFrame(precipResults)
df2.columns = ["date", "prcp"]
df2.head()
# Out:
#          date  prcp
# 0  2016-08-24  0.08
# 1  2016-08-25  0.08
# 2  2016-08-26  0.00
# 3  2016-08-27  0.00
# 4  2016-08-28  0.01

# %%
plt.plot(df.sort_values(by="date", ascending=True).date, df.sort_values(by="date", ascending=True).prcp)
plt.title("Precipitation - Honolulu, HI")
plt.ylabel("Precipitation in Inches")
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
df.describe()
# Out:
#               prcp
# count  2015.000000
# mean      0.176462
# std       0.460288
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.130000
# max       6.700000

# %%
# Design a query to show how many stations are available in this dataset?
station_count = session.query(Station.station).count()

station_count
# Out:
# 9

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
station_measurement = (session.query(Station.station, func.count(Measurement.id))
                       .select_from(Measurement)
                       .join(Station, Measurement.station ==Station.station)
                       .group_by(Station.station)
                       .order_by(func.count(Measurement.id).desc()).all())

station_measurement
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?
active_station = "USC00519281"
temp_info = (session.query(func.min(Measurement.tobs), 
                           func.max(Measurement.tobs), 
                           func.avg(Measurement.tobs))
             .filter(Measurement.station == active_station).all())

temp_info
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
year_temperature = session.query(Measurement.date, Measurement.tobs)
.filter(Measurement.station == active_station)
.filter(func.strftime("%Y-%m-%d", Measurement.date) > startDate).all()

year_temperature_DF = pd.DataFrame(year_temperature, columns = ["Date", "Temperature"])
year_temperature_DF
# Out:
#   File "<ipython-input-60-bcbb54bd7738>", line 4
#     .filter(Measurement.station == active_station)
#     ^
# SyntaxError: invalid syntax

# %%
year_temperature_DF.plot(kind="hist", bins=12)
plt.title("Temperatures - Honolulu, HI")
plt.xlabel("Farenheit")
# Out:
# Text(0.5, 0, 'Farenheit')

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
trip_dates = "2012-02-28 to \n 2012-03-05"
previous_year_start = "2011-02-28"
previous_year_end = "2011-03-05"

temps = calc_temps(previous_year_start, previous_year_end)

temps
# Out:
# [(61.0, 69.75510204081633, 75.0)]

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)
min_temp = temps[0][0]
avg_temp = temps[0][1]
max_temp = temps[0][2]

peak_to_peak = temps[0][2] - temps[0][0]

plt.bar(trip_dates, avg_temp, yerr = peak_to_peak)
plt.xlim(-1, 1)
plt.title("Trip Avg Temp")
plt.ylabel("Fahrenheit")
# Out:
# Text(0, 0.5, 'Fahrenheit')

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation
sel = ([func.sum(Measurement.prcp),
        Station.station, 
        Station.name, 
        Station.latitude, 
        Station.longitude, 
        Station.elevation])

total_rain = (session.query(*sel)
               .filter(Station.station == Measurement.station)
               .filter(Measurement.date >= previous_year_start)
               .filter(Measurement.date <= previous_year_end)
               .group_by(Station.station)
               .order_by(func.sum(Measurement.prcp).desc()).all())

total_rain_DF = pd.DataFrame(total_rain, columns = ["Precipitation", "Station", "Name", "Latitude", "Longitude", "Elevation"])
total_rain_DF
# Out:
#    Precipitation      Station                                    Name  \
# 0           2.33  USC00518838              UPPER WAHIAWA 874.3, HI US
# 1           2.23  USC00519281                     WAIHEE 837.5, HI US
# 2           2.19  USC00519523      WAIMANALO EXPERIMENTAL FARM, HI US
# 3           1.96  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US
# 4           1.45  USC00516128            MANOA LYON ARBO 785.2, HI US
# 5           1.44  USC00513117                    KANEOHE 838.1, HI US
# 6           1.38  USC00519397                    WAIKIKI 717.2, HI US
# 7           0.63  USC00511918       HONOLULU OBSERVATORY 702.2, HI US
# 8            NaN  USC00517948                       PEARL CITY, HI US
#
#    Latitude  Longitude  Elevation
# 0  21.49920 -158.01110      306.6
# 1  21.45167 -157.84889       32.9
# 2  21.33556 -157.71139       19.5
# 3  21.52130 -157.83740        7.0
# 4  21.33310 -157.80250      152.4
# 5  21.42340 -157.80150       14.6
# ...
